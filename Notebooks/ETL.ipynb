# %% [markdown]
# # ETL (Extracción, Transformación y Carga) para el conjunto de datos

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut

# %% [markdown]
# ## Creación de los Datasets
# Cargamos archivo Excel y procedemos a leer la información

# %%
# Cargando el archivo Excel
hechos_df = pd.read_excel('../Datasets/homicidios.xlsx', sheet_name= "HECHOS")
victimas_df = pd.read_excel('../Datasets/homicidios.xlsx', sheet_name= "VICTIMAS")

# %% [markdown]
# ## Dataset Hechos
# Visualizando las primeras filas de cada hoja para entender la estructura de los datos.

# %%
hechos_df.head()
# Out:
#           ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA HH  \
# 0  2016-0001           1 2016-01-01  2016   1   1  04:00:00  4
# 1  2016-0002           1 2016-01-02  2016   1   2  01:15:00  1
# 2  2016-0003           1 2016-01-03  2016   1   3  07:00:00  7
# 3  2016-0004           1 2016-01-10  2016   1  10  00:00:00  0
# 4  2016-0005           1 2016-01-21  2016   1  21  05:20:00  5
#
#                              LUGAR_DEL_HECHO TIPO_DE_CALLE  ...  Altura  \
# 0  AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA  ...     NaN
# 1          AV GRAL PAZ  Y AV DE LOS CORRALES      GRAL PAZ  ...     NaN
# 2                         AV ENTRE RIOS 2034       AVENIDA  ...  2034.0
# 3      AV LARRAZABAL Y GRAL VILLEGAS CONRADO       AVENIDA  ...     NaN
# 4  AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA        AVENIDA  ...     NaN
#
#                                  Cruce  \
# 0  FERNANDEZ DE LA CRUZ, F., GRAL. AV.
# 1                  DE LOS CORRALES AV.
# 2                                  NaN
# 3             VILLEGAS, CONRADO, GRAL.
# 4              SAENZ PE?A, LUIS, PRES.
#
#                                Dirección Normalizada COMUNA  \
# 0  PIEDRA BUENA AV. y FERNANDEZ DE LA CRUZ, F., G...      8
# 1               PAZ, GRAL. AV. y DE LOS CORRALES AV.      9
# 2                                ENTRE RIOS AV. 2034      1
# 3          LARRAZABAL AV. y VILLEGAS, CONRADO, GRAL.      8
# 4            SAN JUAN AV. y SAENZ PEÃ‘A, LUIS, PRES.      1
#
#                                  XY (CABA)         pos x         pos y  \
# 0    Point (98896.78238426 93532.43437792)  -58.47533969  -34.68757022
# 1    Point (95832.05571093 95505.41641999)  -58.50877521  -34.66977709
# 2   Point (106684.29090040 99706.57687843)  -58.39040293  -34.63189362
# 3    Point (99840.65224780 94269.16534422)  -58.46503904  -34.68092974
# 4  Point (106980.32827929 100752.16915795)  -58.38718297  -34.62246630
#
#     PARTICIPANTES VICTIMA    ACUSADO
# 0       MOTO-AUTO    MOTO       AUTO
# 1  AUTO-PASAJEROS    AUTO  PASAJEROS
# 2       MOTO-AUTO    MOTO       AUTO
# 3         MOTO-SD    MOTO         SD
# 4  MOTO-PASAJEROS    MOTO  PASAJEROS
#
# [5 rows x 21 columns]

# %%
victimas_df.head()
# Out:
#     ID_hecho      FECHA  AAAA  MM  DD        ROL VICTIMA       SEXO EDAD  \
# 0  2016-0001 2016-01-01  2016   1   1  CONDUCTOR    MOTO  MASCULINO   19
# 1  2016-0002 2016-01-02  2016   1   2  CONDUCTOR    AUTO  MASCULINO   70
# 2  2016-0003 2016-01-03  2016   1   3  CONDUCTOR    MOTO  MASCULINO   30
# 3  2016-0004 2016-01-10  2016   1  10  CONDUCTOR    MOTO  MASCULINO   18
# 4  2016-0005 2016-01-21  2016   1  21  CONDUCTOR    MOTO  MASCULINO   29
#
#    FECHA_FALLECIMIENTO
# 0  2016-01-01 00:00:00
# 1  2016-01-02 00:00:00
# 2  2016-01-03 00:00:00
# 3                   SD
# 4  2016-02-01 00:00:00

# %% [markdown]
# Verificando si hay valores faltantes en las hojas 'HECHOS' y 'VICTIMAS'

# %%
hechos_df.isnull().sum()
# Out:
# ID                         0
# N_VICTIMAS                 0
# FECHA                      0
# AAAA                       0
# MM                         0
# DD                         0
# HORA                       0
# HH                         0
# LUGAR_DEL_HECHO            0
# TIPO_DE_CALLE              0
# Calle                      1
# Altura                   567
# Cruce                    171
# Dirección Normalizada      8
# COMUNA                     0
# XY (CABA)                  0
# pos x                      0
# pos y                      0
# PARTICIPANTES              0
# VICTIMA                    0
# ACUSADO                    0
# dtype: int64

# %%
victimas_df.isnull().sum()
# Out:
# ID_hecho               0
# FECHA                  0
# AAAA                   0
# MM                     0
# DD                     0
# ROL                    0
# VICTIMA                0
# SEXO                   0
# EDAD                   0
# FECHA_FALLECIMIENTO    0
# dtype: int64

# %% [markdown]
# Realizando una revisión manual en el archivo Excel, se valida que algunos registros no tienen la información completa en las columnas 'XY (CABA)', 'pos x' y 'pos y', especialmente la columna 'XY (CABA)' que tiene información incompleta como 'Point (. .)'; se procede a separar los registros incompletos en un Dataframe para posteriormente completarlos.

# %%
sinXY_df = hechos_df[hechos_df['XY (CABA)']=='Point (. .)'][['ID','LUGAR_DEL_HECHO', 'Dirección Normalizada', 'XY (CABA)', 'pos x', 'pos y']]
sinXY_df
# Out:
#             ID                                    LUGAR_DEL_HECHO  \
# 35   2016-0049  AUTOPISTA 1 SUR PRESIDENTE ARTURO FRONDIZI KM....
# 38   2016-0052                         AUTOPISTA LUGONES PK 10000
# 71   2016-0096       AUTOPISTA DELLEPIANE LUIS TTE. GRAL. KM. 2,3
# 106  2016-0136                   AU BUENOS AIRES - LA PLATA KM. 4
# 119  2016-0151                                                 SD
# 139  2016-0174                               AUTOPISTA 25 DE MAYO
# 176  2017-0042                      AV. LEOPOLDO LUGONES PKM 6900
# 180  2017-0050            AU PERITO MORENO Y RAMAL ENLACE AU1/AU6
# 181  2017-0051                                 AU DELLEPIANE 2400
# 256  2017-0140                        AU ARTURO FRONDIZI PKM 3100
# 313  2018-0039                           AUTOPISTA LUGONES KM 4.7
# 546  2020-0026                       LUGONES, LEOPOLDO AV. KM 6,1
# 559  2020-0039                                    MURGUIONDO 2700
# 621  2021-0023                   AU BUENOS AIRES LA PLATA  KM 4,5
#
#                           Dirección Normalizada    XY (CABA)  \
# 35   AUTOPISTA 1 SUR PRESIDENTE ARTURO FRONDIZI  Point (. .)
# 38                                          NaN  Point (. .)
# 71         AUTOPISTA DELLEPIANE LUIS TTE. GRAL.  Point (. .)
# 106                                         NaN  Point (. .)
# 119                                         NaN  Point (. .)
# 139                        AUTOPISTA 25 DE MAYO  Point (. .)
# 176                       LUGONES, LEOPOLDO AV.  Point (. .)
# 180                                         NaN  Point (. .)
# 181                                         NaN  Point (. .)
# 256  AUTOPISTA 1 SUR PRESIDENTE ARTURO FRONDIZI  Point (. .)
# 313                                         NaN  Point (. .)
# 546                                         NaN  Point (. .)
# 559                                  MURGUIONDO  Point (. .)
# 621                                         NaN  Point (. .)
#
#                   pos x               pos y
# 35   -58.37714647568196  -34.63657525428238
# 38                    .                   .
# 71   -58.47433193007387  -34.66684950051973
# 106                   .                   .
# 119                   .                   .
# 139                   .                   .
# 176                   .                   .
# 180                   .                   .
# 181                   .                   .
# 256                   .                   .
# 313                   .                   .
# 546                   .                   .
# 559                   .                   .
# 621                   .                   .

# %% [markdown]
# ### Limpieza de datos
# Utilizando la libreria `geopy` con su clase `Nominatim` se completará las coordenadas faltantes.

# %%
geolocalizador = Nominatim(user_agent="myGeocoder", timeout=20)

# Creamos la función geolocalizar que se utilizará para enviar la dirección y retornar la geolocalización
def geolocalizar(address):
     try:
          if 'Buenos Aires, Argentina' not in address:
               address += ', Buenos Aires, Argentina'
          location = geolocalizador.geocode(address)
          return (location.latitude, location.longitude)
     except Exception as e:
          return (None, None)

# %% [markdown]
# Agregamos una columna 'coordenadas' a sinXY_df, convirtiendo direcciones en 'LUGAR_DEL_HECHO' a coordenadas geográficas mediante la función geolocalizar, y asigna None en caso de falla en la geolocalización.

# %%
sinXY_df['coordenadas'] =sinXY_df['LUGAR_DEL_HECHO'].apply(geolocalizar)
sinXY_df
# Out:
#             ID                                    LUGAR_DEL_HECHO  \
# 35   2016-0049  AUTOPISTA 1 SUR PRESIDENTE ARTURO FRONDIZI KM....
# 38   2016-0052                         AUTOPISTA LUGONES PK 10000
# 71   2016-0096       AUTOPISTA DELLEPIANE LUIS TTE. GRAL. KM. 2,3
# 106  2016-0136                   AU BUENOS AIRES - LA PLATA KM. 4
# 119  2016-0151                                                 SD
# 139  2016-0174                               AUTOPISTA 25 DE MAYO
# 176  2017-0042                      AV. LEOPOLDO LUGONES PKM 6900
# 180  2017-0050            AU PERITO MORENO Y RAMAL ENLACE AU1/AU6
# 181  2017-0051                                 AU DELLEPIANE 2400
# 256  2017-0140                        AU ARTURO FRONDIZI PKM 3100
# 313  2018-0039                           AUTOPISTA LUGONES KM 4.7
# 546  2020-0026                       LUGONES, LEOPOLDO AV. KM 6,1
# 559  2020-0039                                    MURGUIONDO 2700
# 621  2021-0023                   AU BUENOS AIRES LA PLATA  KM 4,5
#
#                           Dirección Normalizada    XY (CABA)  \
# 35   AUTOPISTA 1 SUR PRESIDENTE ARTURO FRONDIZI  Point (. .)
# 38                                          NaN  Point (. .)
# 71         AUTOPISTA DELLEPIANE LUIS TTE. GRAL.  Point (. .)
# 106                                         NaN  Point (. .)
# 119                                         NaN  Point (. .)
# 139                        AUTOPISTA 25 DE MAYO  Point (. .)
# 176                       LUGONES, LEOPOLDO AV.  Point (. .)
# 180                                         NaN  Point (. .)
# 181                                         NaN  Point (. .)
# 256  AUTOPISTA 1 SUR PRESIDENTE ARTURO FRONDIZI  Point (. .)
# 313                                         NaN  Point (. .)
# 546                                         NaN  Point (. .)
# 559                                  MURGUIONDO  Point (. .)
# 621                                         NaN  Point (. .)
#
#                   pos x               pos y   coordenadas
# 35   -58.37714647568196  -34.63657525428238  (None, None)
# 38                    .                   .  (None, None)
# 71   -58.47433193007387  -34.66684950051973  (None, None)
# 106                   .                   .  (None, None)
# 119                   .                   .  (None, None)
# 139                   .                   .  (None, None)
# 176                   .                   .  (None, None)
# 180                   .                   .  (None, None)
# 181                   .                   .  (None, None)
# 256                   .                   .  (None, None)
# 313                   .                   .  (None, None)
# 546                   .                   .  (None, None)
# 559                   .                   .  (None, None)
# 621                   .                   .  (None, None)

# %% [markdown]
# Dado que son pocos datos, se realiza la actualización manualmente para los ID: 139, 181 Y 559

# %%
# Lista de IDs para geolocalizar
ids_a_geolocalizar = [139, 181, 559]

# Iterando sobre los IDs
for id in ids_a_geolocalizar:
    if id in hechos_df.index:
        lat, lon = geolocalizar(hechos_df.at[id, 'LUGAR_DEL_HECHO'])
        hechos_df.at[id, 'pos y'] = lat
        hechos_df.at[id, 'pos x'] = lon

# %% [markdown]
# Con la finalidad de terminar de completar los datos vacíos, se reemplazará para la columna 'XY (CABA)' los valores 'Point (. .)' por 0, en las columnas 'pos x' y 'pos y' los '.' por 0

# %%
hechos_df['pos x'] = hechos_df['pos x'].replace('.', 0)
hechos_df['pos y'] = hechos_df['pos y'].replace('.', 0)
hechos_df['XY (CABA)'] = hechos_df['XY (CABA)'].replace('Point (. .)', 0)

# %% [markdown]
# Columnas "Cruce" y "Altura"
# La columna "Cruce" indica si el accidente ocurrió en una intersección de vías, mientras que la columna "Altura" indica si el accidente ocurrio en mitad de una vía. Con la finalidad de reducir la cantidad de campos vacíos, se procede a trabajar con la columna "Cruce", para los registros que los accidentes fueron en un cruce el valor será `True` y para los casos que los accidentes ocurrieron en una altura el valor será `False`

# %%
hechos_df.head()
# Out:
#           ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA HH  \
# 0  2016-0001           1 2016-01-01  2016   1   1  04:00:00  4
# 1  2016-0002           1 2016-01-02  2016   1   2  01:15:00  1
# 2  2016-0003           1 2016-01-03  2016   1   3  07:00:00  7
# 3  2016-0004           1 2016-01-10  2016   1  10  00:00:00  0
# 4  2016-0005           1 2016-01-21  2016   1  21  05:20:00  5
#
#                              LUGAR_DEL_HECHO TIPO_DE_CALLE  ...  Altura  \
# 0  AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA  ...     NaN
# 1          AV GRAL PAZ  Y AV DE LOS CORRALES      GRAL PAZ  ...     NaN
# 2                         AV ENTRE RIOS 2034       AVENIDA  ...  2034.0
# 3      AV LARRAZABAL Y GRAL VILLEGAS CONRADO       AVENIDA  ...     NaN
# 4  AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA        AVENIDA  ...     NaN
#
#                                  Cruce  \
# 0  FERNANDEZ DE LA CRUZ, F., GRAL. AV.
# 1                  DE LOS CORRALES AV.
# 2                                  NaN
# 3             VILLEGAS, CONRADO, GRAL.
# 4              SAENZ PE?A, LUIS, PRES.
#
#                                Dirección Normalizada COMUNA  \
# 0  PIEDRA BUENA AV. y FERNANDEZ DE LA CRUZ, F., G...      8
# 1               PAZ, GRAL. AV. y DE LOS CORRALES AV.      9
# 2                                ENTRE RIOS AV. 2034      1
# 3          LARRAZABAL AV. y VILLEGAS, CONRADO, GRAL.      8
# 4            SAN JUAN AV. y SAENZ PEÃ‘A, LUIS, PRES.      1
#
#                                  XY (CABA)         pos x         pos y  \
# 0    Point (98896.78238426 93532.43437792)  -58.47533969  -34.68757022
# 1    Point (95832.05571093 95505.41641999)  -58.50877521  -34.66977709
# 2   Point (106684.29090040 99706.57687843)  -58.39040293  -34.63189362
# 3    Point (99840.65224780 94269.16534422)  -58.46503904  -34.68092974
# 4  Point (106980.32827929 100752.16915795)  -58.38718297  -34.62246630
#
#     PARTICIPANTES VICTIMA    ACUSADO
# 0       MOTO-AUTO    MOTO       AUTO
# 1  AUTO-PASAJEROS    AUTO  PASAJEROS
# 2       MOTO-AUTO    MOTO       AUTO
# 3         MOTO-SD    MOTO         SD
# 4  MOTO-PASAJEROS    MOTO  PASAJEROS
#
# [5 rows x 21 columns]

# %%
hechos_df = hechos_df.drop('Altura', axis=1)

# %%
hechos_df['Cruce'] = hechos_df['Cruce'].notna()
hechos_df.head(20)
# Out:
#            ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA  HH  \
# 0   2016-0001           1 2016-01-01  2016   1   1  04:00:00   4
# 1   2016-0002           1 2016-01-02  2016   1   2  01:15:00   1
# 2   2016-0003           1 2016-01-03  2016   1   3  07:00:00   7
# 3   2016-0004           1 2016-01-10  2016   1  10  00:00:00   0
# 4   2016-0005           1 2016-01-21  2016   1  21  05:20:00   5
# 5   2016-0008           1 2016-01-24  2016   1  24  18:30:00  18
# 6   2016-0009           1 2016-01-24  2016   1  24  19:10:00  19
# 7   2016-0010           1 2016-01-29  2016   1  29  15:20:00  15
# 8   2016-0012           1 2016-02-08  2016   2   8  01:20:00   1
# 9   2016-0013           1 2016-02-10  2016   2  10  11:30:00  11
# 10  2016-0015           1 2016-02-14  2016   2  14  05:14:00   5
# 11  2016-0016           1 2016-02-14  2016   2  14  22:00:00  22
# 12  2016-0017           1 2016-02-15  2016   2  15  16:54:00  16
# 13  2016-0019           1 2016-02-17  2016   2  17  09:30:00   9
# 14  2016-0020           1 2016-02-17  2016   2  17  16:00:00  16
# 15  2016-0021           1 2016-02-17  2016   2  17  23:35:00  23
# 16  2016-0022           1 2016-02-21  2016   2  21  06:00:00   6
# 17  2016-0025           1 2016-02-28  2016   2  28  04:50:00   4
# 18  2016-0026           1 2016-02-28  2016   2  28  07:30:00   7
# 19  2016-0027           1 2016-02-28  2016   2  28  09:35:00   9
#
#                                       LUGAR_DEL_HECHO TIPO_DE_CALLE  \
# 0           AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA
# 1                   AV GRAL PAZ  Y AV DE LOS CORRALES      GRAL PAZ
# 2                                  AV ENTRE RIOS 2034       AVENIDA
# 3               AV LARRAZABAL Y GRAL VILLEGAS CONRADO       AVENIDA
# 4           AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA        AVENIDA
# 5                      AV 27 DE FEBRERO Y AV ESCALADA       AVENIDA
# 6                        NOGOYA Y JOAQUIN V. GONZALES         CALLE
# 7                 AV GENERAL PAZ Y AV DE LOS CORRALES      GRAL PAZ
# 8                  AV BELGRANO Y BERNARDO DE IRIGOYEN       AVENIDA
# 9                                  AV ENTRE RIOS 1366       AVENIDA
# 10                         AV SCALABRINI ORTIZ Y VERA       AVENIDA
# 11  AV REGIMIENTO DE PATRICIOS Y QUINQUELA MARTIN ...       AVENIDA
# 12                   MARIANO ACOSTA Y ANA MARIA JANER       AVENIDA
# 13  LISANDRO DE LA TORRE Y SEVERO GARCIA GRANDE DE...         CALLE
# 14                                       SUIPACHA 156         CALLE
# 15                        AV DIRECTORIO Y CURAPALIGUE       AVENIDA
# 16                      AV 9 DE JULIO Y ADOLFO ALSINA       AVENIDA
# 17                     AV GRAL PAZ Y AV 27 DE FEBRERO      GRAL PAZ
# 18                                   HOLMBERG Y VEDIA         CALLE
# 19                         CURAPALIGUE Y AVELINO DIAZ       AVENIDA
#
#                           Calle  Cruce  \
# 0              PIEDRA BUENA AV.   True
# 1                PAZ, GRAL. AV.   True
# 2                ENTRE RIOS AV.  False
# 3                LARRAZABAL AV.   True
# 4                  SAN JUAN AV.   True
# 5             27 DE FEBRERO AV.   True
# 6                        NOGOYA   True
# 7                PAZ, GRAL. AV.   True
# 8                  BELGRANO AV.   True
# 9                ENTRE RIOS AV.  False
# 10   SCALABRINI ORTIZ, RAUL AV.   True
# 11  REGIMIENTO DE PATRICIOS AV.   True
# 12              ACOSTA, MARIANO   True
# 13        DE LA TORRE, LISANDRO   True
# 14                     SUIPACHA  False
# 15               DIRECTORIO AV.   True
# 16               9 DE JULIO AV.   True
# 17               PAZ, GRAL. AV.   True
# 18                     HOLMBERG   True
# 19              CURAPALIGUE AV.   True
#
#                                 Dirección Normalizada  COMUNA  \
# 0   PIEDRA BUENA AV. y FERNANDEZ DE LA CRUZ, F., G...       8
# 1                PAZ, GRAL. AV. y DE LOS CORRALES AV.       9
# 2                                 ENTRE RIOS AV. 2034       1
# 3           LARRAZABAL AV. y VILLEGAS, CONRADO, GRAL.       8
# 4             SAN JUAN AV. y SAENZ PEÃ‘A, LUIS, PRES.       1
# 5                    27 DE FEBRERO AV. y ESCALADA AV.       8
# 6                       NOGOYA y GONZALEZ, JOAQUIN V.      11
# 7                PAZ, GRAL. AV. y DE LOS CORRALES AV.       9
# 8                BELGRANO AV. e IRIGOYEN, BERNARDO DE       1
# 9                                 ENTRE RIOS AV. 1366       1
# 10                  SCALABRINI ORTIZ, RAUL AV. y VERA      15
# 11  REGIMIENTO DE PATRICIOS AV. y QUINQUELA MARTIN...       4
# 12                 ACOSTA, MARIANO y JANER, ANA MARIA       8
# 13  DE LA TORRE, LISANDRO y GARCIA GRANDE DE ZEQUE...       9
# 14                                       SUIPACHA 156       1
# 15                       DIRECTORIO AV. y CURAPALIGUE       7
# 16                    9 DE JULIO AV. y ALSINA, ADOLFO       1
# 17                 PAZ, GRAL. AV. y 27 DE FEBRERO AV.       8
# 18                                   HOLMBERG y VEDIA      12
# 19                    CURAPALIGUE AV. y DIAZ, AVELINO       7
#
#                                   XY (CABA)         pos x         pos y  \
# 0     Point (98896.78238426 93532.43437792)  -58.47533969  -34.68757022
# 1     Point (95832.05571093 95505.41641999)  -58.50877521  -34.66977709
# 2    Point (106684.29090040 99706.57687843)  -58.39040293  -34.63189362
# 3     Point (99840.65224780 94269.16534422)  -58.46503904  -34.68092974
# 4   Point (106980.32827929 100752.16915795)  -58.38718297  -34.62246630
# 5    Point (101721.59002217 93844.25656649)  -58.44451316  -34.68475866
# 6    Point (96545.87592078 102330.67262199)  -58.50095869  -34.60825440
# 7     Point (95832.05571093 95505.41641999)  -58.50877521  -34.66977709
# 8   Point (107595.35084333 101797.50052813)  -58.38048577  -34.61303893
# 9   Point (106616.41069662 100496.44662323)  -58.39114932  -34.62477387
# 10  Point (102357.43746828 103343.52002839)  -58.43760020  -34.59912758
# 11   Point (108661.59115206 98481.75445555)  -58.36882665  -34.64291993
# 12   Point (101228.61094416 96623.72136186)  -58.44989671  -34.65970435
# 13    Point (95727.37083199 97179.35560349)  -58.50990884  -34.65468721
# 14  Point (107684.31807562 102519.17333314)  -58.37952223  -34.60653282
# 15   Point (101074.94198885 99848.19369046)  -58.45157703  -34.63063795
# 16  Point (107507.39502374 102046.08333077)  -58.38144696  -34.61079875
# 17   Point (100077.95205948 91571.23307293)  -58.46244952  -34.70524971
# 18   Point (97350.75566590 109083.19420265)  -58.49216191  -34.54738649
# 19   Point (101679.82794245 98973.02976850)  -58.44497874  -34.63852623
#
#        PARTICIPANTES VICTIMA      ACUSADO
# 0          MOTO-AUTO    MOTO         AUTO
# 1     AUTO-PASAJEROS    AUTO    PASAJEROS
# 2          MOTO-AUTO    MOTO         AUTO
# 3            MOTO-SD    MOTO           SD
# 4     MOTO-PASAJEROS    MOTO    PASAJEROS
# 5   MOTO-OBJETO FIJO    MOTO  OBJETO FIJO
# 6          MOTO-AUTO    MOTO         AUTO
# 7          MOTO-AUTO    MOTO         AUTO
# 8        MOTO-CARGAS    MOTO       CARGAS
# 9        PEATON-AUTO  PEATON         AUTO
# 10       PEATON-AUTO  PEATON         AUTO
# 11         MOTO-AUTO    MOTO         AUTO
# 12       PEATON-MOTO  PEATON         MOTO
# 13  PEATON-PASAJEROS  PEATON    PASAJEROS
# 14       PEATON-AUTO  PEATON         AUTO
# 15         AUTO-AUTO    AUTO         AUTO
# 16         MOTO-AUTO    MOTO         AUTO
# 17         AUTO-AUTO    AUTO         AUTO
# 18  AUTO-OBJETO FIJO    AUTO  OBJETO FIJO
# 19         AUTO-AUTO    AUTO         AUTO

# %% [markdown]
# ### Columna ID
# Validando que no exista duplicados en la columna ID, columna principal para relacionar con la información del dataframe Víctimas.

# %%
hechos_df['ID'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Columnas del tipo fecha (FECHA, AAAA, DD, HORA y HH)
# Realizando una revisión en el archivo Excel, se encuentra un caracter en la columna 'HORA' y 'HH' que no corresponde al tipo fecha. Se procede a realizar la actualización del valor a 0, para no perder el resto de información de las columnas relevantes de dicho registro.

# %%
hechos_df[hechos_df['HORA'] == 'SD']
# Out:
#             ID  N_VICTIMAS      FECHA  AAAA  MM  DD HORA  HH  \
# 518  2019-0103           1 2019-12-18  2019  12  18   SD  SD
#
#              LUGAR_DEL_HECHO TIPO_DE_CALLE           Calle  Cruce  \
# 518  PAZ, GRAL. AV. Y GRIVEO      GRAL PAZ  PAZ, GRAL. AV.   True
#
#        Dirección Normalizada  COMUNA                               XY (CABA)  \
# 518  PAZ, GRAL. AV. y GRIVEO      11  Point (94643.11254058 103831.57115061)
#
#             pos x         pos y PARTICIPANTES VICTIMA ACUSADO
# 518  -58.52169422  -34.59471640     MOTO-MOTO    MOTO    MOTO

# %%
hechos_df['HORA'][518] = 0
hechos_df['HH'][518] = 0

hechos_df.loc[518][['HORA', 'HH', ]]
# Out:
# HORA    0
# HH      0
# Name: 518, dtype: object

# %% [markdown]
# ### Columna Dirección Normalizada y Calle
# Se había detectado algunos valores nulos en esta columna, considerando que 'SD' son las siglas de 'Sin Datos' se procede a rellenar las columnas vacías con 'SD'.

# %% [markdown]
# Empezamos filtrando los valores nulos en la columna 'Dirección Normalizada'.

# %%
hechos_df[hechos_df['Dirección Normalizada'].isnull()][['ID', 'LUGAR_DEL_HECHO', 'TIPO_DE_CALLE', 'Calle', 'Dirección Normalizada']]
# Out:
#             ID                          LUGAR_DEL_HECHO TIPO_DE_CALLE  \
# 38   2016-0052               AUTOPISTA LUGONES PK 10000     AUTOPISTA
# 106  2016-0136         AU BUENOS AIRES - LA PLATA KM. 4     AUTOPISTA
# 119  2016-0151                                       SD         CALLE
# 180  2017-0050  AU PERITO MORENO Y RAMAL ENLACE AU1/AU6     AUTOPISTA
# 181  2017-0051                       AU DELLEPIANE 2400     AUTOPISTA
# 313  2018-0039                 AUTOPISTA LUGONES KM 4.7     AUTOPISTA
# 546  2020-0026             LUGONES, LEOPOLDO AV. KM 6,1     AUTOPISTA
# 621  2021-0023         AU BUENOS AIRES LA PLATA  KM 4,5     AUTOPISTA
#
#                                     Calle Dirección Normalizada
# 38                  LUGONES, LEOPOLDO AV.                   NaN
# 106     AUTOPISTA BUENOS AIRES - LA PLATA                   NaN
# 119                                   NaN                   NaN
# 180               AUTOPISTA PERITO MORENO                   NaN
# 181  AUTOPISTA DELLEPIANE LUIS TTE. GRAL.                   NaN
# 313                 LUGONES, LEOPOLDO AV.                   NaN
# 546                 LUGONES, LEOPOLDO AV.                   NaN
# 621     AUTOPISTA BUENOS AIRES - LA PLATA                   NaN

# %%
hechos_df['Dirección Normalizada'].fillna('SD', inplace=True)

hechos_df[hechos_df['Dirección Normalizada'] == 'SD'][['ID', 'LUGAR_DEL_HECHO', 'TIPO_DE_CALLE', 'Calle', 'Dirección Normalizada']]
# Out:
#             ID                          LUGAR_DEL_HECHO TIPO_DE_CALLE  \
# 38   2016-0052               AUTOPISTA LUGONES PK 10000     AUTOPISTA
# 106  2016-0136         AU BUENOS AIRES - LA PLATA KM. 4     AUTOPISTA
# 119  2016-0151                                       SD         CALLE
# 180  2017-0050  AU PERITO MORENO Y RAMAL ENLACE AU1/AU6     AUTOPISTA
# 181  2017-0051                       AU DELLEPIANE 2400     AUTOPISTA
# 313  2018-0039                 AUTOPISTA LUGONES KM 4.7     AUTOPISTA
# 546  2020-0026             LUGONES, LEOPOLDO AV. KM 6,1     AUTOPISTA
# 621  2021-0023         AU BUENOS AIRES LA PLATA  KM 4,5     AUTOPISTA
#
#                                     Calle Dirección Normalizada
# 38                  LUGONES, LEOPOLDO AV.                    SD
# 106     AUTOPISTA BUENOS AIRES - LA PLATA                    SD
# 119                                   NaN                    SD
# 180               AUTOPISTA PERITO MORENO                    SD
# 181  AUTOPISTA DELLEPIANE LUIS TTE. GRAL.                    SD
# 313                 LUGONES, LEOPOLDO AV.                    SD
# 546                 LUGONES, LEOPOLDO AV.                    SD
# 621     AUTOPISTA BUENOS AIRES - LA PLATA                    SD

# %% [markdown]
# Realizamos el mismo proceso con la columna 'Calle'

# %%
hechos_df[hechos_df['Calle'].isnull()][['ID', 'LUGAR_DEL_HECHO', 'TIPO_DE_CALLE', 'Calle', 'Dirección Normalizada']]
# Out:
#             ID LUGAR_DEL_HECHO TIPO_DE_CALLE Calle Dirección Normalizada
# 119  2016-0151              SD         CALLE   NaN                    SD

# %%
hechos_df['Calle'].fillna('SD', inplace=True)

hechos_df[hechos_df['Calle'] == 'SD'][['ID', 'LUGAR_DEL_HECHO', 'TIPO_DE_CALLE', 'Calle', 'Dirección Normalizada']]
# Out:
#             ID LUGAR_DEL_HECHO TIPO_DE_CALLE Calle Dirección Normalizada
# 119  2016-0151              SD         CALLE    SD                    SD

# %% [markdown]
# Volvemos a revisar que no tengamos valores nulos.

# %%
hechos_df.isnull().sum()
# Out:
# ID                       0
# N_VICTIMAS               0
# FECHA                    0
# AAAA                     0
# MM                       0
# DD                       0
# HORA                     0
# HH                       0
# LUGAR_DEL_HECHO          0
# TIPO_DE_CALLE            0
# Calle                    0
# Cruce                    0
# Dirección Normalizada    0
# COMUNA                   0
# XY (CABA)                0
# pos x                    3
# pos y                    3
# PARTICIPANTES            0
# VICTIMA                  0
# ACUSADO                  0
# dtype: int64

# %% [markdown]
# Revisamos los tipos de datos de cada columna

# %%
hechos_df.dtypes
# Out:
# ID                               object
# N_VICTIMAS                        int64
# FECHA                    datetime64[ns]
# AAAA                              int64
# MM                                int64
# DD                                int64
# HORA                             object
# HH                               object
# LUGAR_DEL_HECHO                  object
# TIPO_DE_CALLE                    object
# Calle                            object
# Cruce                              bool
# Dirección Normalizada            object
# COMUNA                            int64
# XY (CABA)                        object
# pos x                            object
# pos y                            object
# PARTICIPANTES                    object
# VICTIMA                          object
# ACUSADO                          object
# dtype: object

# %% [markdown]
# Guardamos el Dataset en formato CSV para trabajarlo posteriormente.

# %%
hechos_df.to_csv('../Datasets/homicidios_hechos.csv')

# %% [markdown]
# ## Dataset Victimas
# Realizamos una revisión de los datos en el dataset `victimas_df`

# %%
victimas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID_hecho             717 non-null    object
#  1   FECHA                717 non-null    datetime64[ns]
#  2   AAAA                 717 non-null    int64
#  3   MM                   717 non-null    int64
#  4   DD                   717 non-null    int64
#  5   ROL                  717 non-null    object
#  6   VICTIMA              717 non-null    object
#  7   SEXO                 717 non-null    object
#  8   EDAD                 717 non-null    object
#  9   FECHA_FALLECIMIENTO  717 non-null    object
# dtypes: datetime64[ns](1), int64(3), object(6)
# memory usage: 56.1+ KB

# %% [markdown]
# Hacemos una busqueda global de registros nulos, pero comprobamos que no hay.

# %%
victimas_df.isnull().sum()
# Out:
# ID_hecho               0
# FECHA                  0
# AAAA                   0
# MM                     0
# DD                     0
# ROL                    0
# VICTIMA                0
# SEXO                   0
# EDAD                   0
# FECHA_FALLECIMIENTO    0
# dtype: int64

# %%
victimas_df.head(20)
# Out:
#      ID_hecho      FECHA  AAAA  MM  DD                   ROL VICTIMA  \
# 0   2016-0001 2016-01-01  2016   1   1             CONDUCTOR    MOTO
# 1   2016-0002 2016-01-02  2016   1   2             CONDUCTOR    AUTO
# 2   2016-0003 2016-01-03  2016   1   3             CONDUCTOR    MOTO
# 3   2016-0004 2016-01-10  2016   1  10             CONDUCTOR    MOTO
# 4   2016-0005 2016-01-21  2016   1  21             CONDUCTOR    MOTO
# 5   2016-0008 2016-01-24  2016   1  24             CONDUCTOR    MOTO
# 6   2016-0009 2016-01-24  2016   1  24  PASAJERO_ACOMPAÑANTE    MOTO
# 7   2016-0010 2016-01-29  2016   1  29             CONDUCTOR    MOTO
# 8   2016-0012 2016-02-08  2016   2   8             CONDUCTOR    MOTO
# 9   2016-0013 2016-02-10  2016   2  10                PEATON  PEATON
# 10  2016-0015 2016-02-14  2016   2  14                PEATON  PEATON
# 11  2016-0016 2016-02-14  2016   2  14  PASAJERO_ACOMPAÑANTE    MOTO
# 12  2016-0017 2016-02-15  2016   2  15                PEATON  PEATON
# 13  2016-0019 2016-02-17  2016   2  17                PEATON  PEATON
# 14  2016-0020 2016-02-17  2016   2  17                PEATON  PEATON
# 15  2016-0021 2016-02-17  2016   2  17             CONDUCTOR    AUTO
# 16  2016-0022 2016-02-21  2016   2  21  PASAJERO_ACOMPAÑANTE    MOTO
# 17  2016-0025 2016-02-28  2016   2  28  PASAJERO_ACOMPAÑANTE    AUTO
# 18  2016-0026 2016-02-28  2016   2  28             CONDUCTOR    AUTO
# 19  2016-0027 2016-02-28  2016   2  28  PASAJERO_ACOMPAÑANTE    AUTO
#
#          SEXO EDAD  FECHA_FALLECIMIENTO
# 0   MASCULINO   19  2016-01-01 00:00:00
# 1   MASCULINO   70  2016-01-02 00:00:00
# 2   MASCULINO   30  2016-01-03 00:00:00
# 3   MASCULINO   18                   SD
# 4   MASCULINO   29  2016-02-01 00:00:00
# 5   MASCULINO   30  2016-01-24 00:00:00
# 6   MASCULINO   29  2016-01-26 00:00:00
# 7   MASCULINO   18  2016-01-29 00:00:00
# 8   MASCULINO   22  2016-02-08 00:00:00
# 9   MASCULINO   16  2016-02-10 00:00:00
# 10   FEMENINO   16  2016-02-14 00:00:00
# 11   FEMENINO   19  2016-02-14 00:00:00
# 12  MASCULINO   59  2016-02-16 00:00:00
# 13   FEMENINO   65  2016-02-17 00:00:00
# 14  MASCULINO   59  2016-03-02 00:00:00
# 15  MASCULINO   34  2016-02-17 00:00:00
# 16  MASCULINO   41                   SD
# 17  MASCULINO   34  2016-02-28 00:00:00
# 18  MASCULINO   30  2016-03-04 00:00:00
# 19  MASCULINO   34                   SD

# %% [markdown]
# Revisión de duplicados, esto me permitirá saber si existen registros duplicados en el dataframe de Víctimas.

# %%
victimas_df[victimas_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID_hecho, FECHA, AAAA, MM, DD, ROL, VICTIMA, SEXO, EDAD, FECHA_FALLECIMIENTO]
# Index: []

# %% [markdown]
# En la revisión de columnas, se encontró 68 registros con valores 'SD' en la columna 'FECHA_FALLECIMIENTO', dado que queremos utilizar esta columna, se requiere actualizar los valores a un formato fecha, para estos casos se actualizará con la columna fecha para poder utilizarlo posteriormente en los reportes.

# %%
victimas_df.loc[victimas_df['FECHA_FALLECIMIENTO'] == 'SD', 'FECHA_FALLECIMIENTO'] = victimas_df['FECHA']

victimas_df.loc[victimas_df['FECHA_FALLECIMIENTO'] == 'SD']
# Out:
# Empty DataFrame
# Columns: [ID_hecho, FECHA, AAAA, MM, DD, ROL, VICTIMA, SEXO, EDAD, FECHA_FALLECIMIENTO]
# Index: []

# %% [markdown]
# Continuamos revisando el resto de columnas.

# %%
victimas_df[victimas_df['ROL']=='SD']
# Out:
#       ID_hecho      FECHA  AAAA  MM  DD ROL VICTIMA       SEXO EDAD  \
# 36   2016-0049 2016-04-17  2016   4  17  SD      SD         SD   SD
# 39   2016-0052 2016-04-20  2016   4  20  SD    MOTO         SD   SD
# 63   2016-0085 2016-06-29  2016   6  29  SD    MOTO  MASCULINO   SD
# 77   2016-0101 2016-08-07  2016   8   7  SD      SD  MASCULINO   67
# 89   2016-0115 2016-09-02  2016   9   2  SD      SD  MASCULINO   SD
# 141  2016-0174 2016-12-27  2016  12  27  SD      SD         SD   SD
# 167  2017-0029 2017-03-07  2017   3   7  SD      SD  MASCULINO   34
# 208  2017-0074 2017-06-04  2017   6   4  SD      SD  MASCULINO   70
# 221  2017-0089 2017-07-13  2017   7  13  SD      SD  MASCULINO   23
# 280  2017-0155 2017-12-12  2017  12  12  SD      SD  MASCULINO   77
# 390  2018-0100 2018-09-20  2018   9  20  SD    MOTO   FEMENINO   33
#
#      FECHA_FALLECIMIENTO
# 36   2016-04-17 00:00:00
# 39   2016-04-20 00:00:00
# 63   2016-06-29 00:00:00
# 77   2016-08-07 00:00:00
# 89   2016-09-02 00:00:00
# 141  2016-12-27 00:00:00
# 167  2017-03-07 00:00:00
# 208  2017-06-04 00:00:00
# 221  2017-07-13 00:00:00
# 280  2017-12-12 00:00:00
# 390  2018-09-20 00:00:00

# %%
victimas_df[victimas_df['VICTIMA']=='SD']
# Out:
#       ID_hecho      FECHA  AAAA  MM  DD                   ROL VICTIMA  \
# 36   2016-0049 2016-04-17  2016   4  17                    SD      SD
# 77   2016-0101 2016-08-07  2016   8   7                    SD      SD
# 89   2016-0115 2016-09-02  2016   9   2                    SD      SD
# 93   2016-0119 2016-09-04  2016   9   4  PASAJERO_ACOMPAÑANTE      SD
# 141  2016-0174 2016-12-27  2016  12  27                    SD      SD
# 167  2017-0029 2017-03-07  2017   3   7                    SD      SD
# 208  2017-0074 2017-06-04  2017   6   4                    SD      SD
# 221  2017-0089 2017-07-13  2017   7  13                    SD      SD
# 280  2017-0155 2017-12-12  2017  12  12                    SD      SD
#
#           SEXO EDAD  FECHA_FALLECIMIENTO
# 36          SD   SD  2016-04-17 00:00:00
# 77   MASCULINO   67  2016-08-07 00:00:00
# 89   MASCULINO   SD  2016-09-02 00:00:00
# 93    FEMENINO   SD  2016-09-04 00:00:00
# 141         SD   SD  2016-12-27 00:00:00
# 167  MASCULINO   34  2017-03-07 00:00:00
# 208  MASCULINO   70  2017-06-04 00:00:00
# 221  MASCULINO   23  2017-07-13 00:00:00
# 280  MASCULINO   77  2017-12-12 00:00:00

# %%
victimas_df[victimas_df['SEXO']=='SD']
# Out:
#       ID_hecho      FECHA  AAAA  MM  DD        ROL VICTIMA SEXO EDAD  \
# 36   2016-0049 2016-04-17  2016   4  17         SD      SD   SD   SD
# 39   2016-0052 2016-04-20  2016   4  20         SD    MOTO   SD   SD
# 108  2016-0136 2016-10-25  2016  10  25  CONDUCTOR    MOTO   SD   SD
# 121  2016-0151 2016-11-18  2016  11  18     PEATON  PEATON   SD   SD
# 138  2016-0171 2016-12-25  2016  12  25  CONDUCTOR    MOTO   SD   SD
# 141  2016-0174 2016-12-27  2016  12  27         SD      SD   SD   SD
#
#      FECHA_FALLECIMIENTO
# 36   2016-04-17 00:00:00
# 39   2016-04-20 00:00:00
# 108  2016-10-25 00:00:00
# 121  2016-11-18 00:00:00
# 138  2016-12-25 00:00:00
# 141  2016-12-27 00:00:00

# %% [markdown]
# En las columnas de ROL, VICTIMA y SEXO, la cantidad de datos sin especificar (SD) es relativamente baja. Específicamente, hay 11 entradas (1.5%) en ROL, 9 entradas (1.3%) en VICTIMA, y 6 entradas (0.8%) en SEXO.
#
# Para evitar dejar estos campos vacíos, se podría reemplazar los valores faltantes en SEXO y ROL con el valor más común encontrado en cada una de estas columnas. Dado que son pocos los datos faltantes, este cambio no debería tener un impacto significativo en los resultados de análisis estadísticos posteriores.
#
# Sin embargo, no modificaré los datos faltantes en la columna VICTIMA para evitar posibles inconsistencias con la información relacionada con las víctimas en el dataframe de Hechos. Cuando se realice la unión (merge) de los dos dataframes, revisaré nuevamente esta columna.

# %%
mostCommonGender = victimas_df['SEXO'].mode().iloc[0]
print(f'Para SEXO, el valor que más se repite es: {mostCommonGender}')
# Out:
# Para SEXO, el valor que más se repite es: MASCULINO

# %%
victimas_df['SEXO'][victimas_df['SEXO'] == 'SD'] = 'MASCULINO'
victimas_df[victimas_df['SEXO'] == 'SD']
# Out:
# Empty DataFrame
# Columns: [ID_hecho, FECHA, AAAA, MM, DD, ROL, VICTIMA, SEXO, EDAD, FECHA_FALLECIMIENTO]
# Index: []

# %%
mostCommonRole = victimas_df['ROL'].mode().iloc[0]
print(f'En ROL, el dato más común es: {mostCommonRole}')
# Out:
# En ROL, el dato más común es: CONDUCTOR

# %%
victimas_df['ROL'][victimas_df['ROL'] == 'SD'] = 'CONDUCTOR'
victimas_df[victimas_df['ROL'] == 'SD']
# Out:
# Empty DataFrame
# Columns: [ID_hecho, FECHA, AAAA, MM, DD, ROL, VICTIMA, SEXO, EDAD, FECHA_FALLECIMIENTO]
# Index: []

# %%
victimas_df[victimas_df['EDAD'] == 'SD'].shape[0]
# Out:
# 53

# %% [markdown]
# La cantidad de datos faltantes en la columna EDAD es considerablemente más alta, aunque sigue representando un porcentaje menor: son 45 registros, lo que equivale a un 6.3%. Mantener estos valores como 'SD' (str) podría causar inconvenientes con el tipo de datos de la columna, y asignarles un valor de 0 podría distorsionar los cálculos estadísticos. Por lo tanto, he decidido utilizar el promedio de edad, diferenciado por el sexo de las víctimas, para completar estos datos faltantes.

# %% [markdown]
# Este método reemplaza todos los casos del valor 'SD' en la columna 'EDAD' por pd.NA. Aquí, pd.NA es una forma de representar un valor "No Disponible" o "faltante" en Pandas.

# %%
victimas_df['EDAD'] = victimas_df['EDAD'].replace('SD', pd.NA)

promedio_por_genero = victimas_df.groupby('SEXO')['EDAD'].mean()
print(f'La edad promedio de FEMENINO es {round(promedio_por_genero["FEMENINO"])} y de MASCULINO es {round(promedio_por_genero["MASCULINO"])}')

victimas_df['EDAD'] = victimas_df.apply(lambda row: promedio_por_genero[row['SEXO']] if pd.isna(row['EDAD']) else row['EDAD'], axis=1)

victimas_df['EDAD'] = victimas_df['EDAD'].astype(int)
# Out:
# La edad promedio de FEMENINO es 51 y de MASCULINO es 40

# %%
victimas_df[victimas_df['EDAD']=='SD']
# Out:
# Empty DataFrame
# Columns: [ID_hecho, FECHA, AAAA, MM, DD, ROL, VICTIMA, SEXO, EDAD, FECHA_FALLECIMIENTO]
# Index: []

# %%
victimas_df.head()
# Out:
#     ID_hecho      FECHA  AAAA  MM  DD        ROL VICTIMA       SEXO  EDAD  \
# 0  2016-0001 2016-01-01  2016   1   1  CONDUCTOR    MOTO  MASCULINO    19
# 1  2016-0002 2016-01-02  2016   1   2  CONDUCTOR    AUTO  MASCULINO    70
# 2  2016-0003 2016-01-03  2016   1   3  CONDUCTOR    MOTO  MASCULINO    30
# 3  2016-0004 2016-01-10  2016   1  10  CONDUCTOR    MOTO  MASCULINO    18
# 4  2016-0005 2016-01-21  2016   1  21  CONDUCTOR    MOTO  MASCULINO    29
#
#    FECHA_FALLECIMIENTO
# 0  2016-01-01 00:00:00
# 1  2016-01-02 00:00:00
# 2  2016-01-03 00:00:00
# 3  2016-01-10 00:00:00
# 4  2016-02-01 00:00:00

# %% [markdown]
# Convertimos el tipo object de la columna 'FECHA_FALLECIMIENTO' a tipo datetime.

# %%
victimas_df['FECHA_FALLECIMIENTO'] = pd.to_datetime(victimas_df['FECHA_FALLECIMIENTO'])

# %%
victimas_df.dtypes
# Out:
# ID_hecho                       object
# FECHA                  datetime64[ns]
# AAAA                            int64
# MM                              int64
# DD                              int64
# ROL                            object
# VICTIMA                        object
# SEXO                           object
# EDAD                            int32
# FECHA_FALLECIMIENTO    datetime64[ns]
# dtype: object

# %%
victimas_df.head()
# Out:
#     ID_hecho      FECHA  AAAA  MM  DD        ROL VICTIMA       SEXO  EDAD  \
# 0  2016-0001 2016-01-01  2016   1   1  CONDUCTOR    MOTO  MASCULINO    19
# 1  2016-0002 2016-01-02  2016   1   2  CONDUCTOR    AUTO  MASCULINO    70
# 2  2016-0003 2016-01-03  2016   1   3  CONDUCTOR    MOTO  MASCULINO    30
# 3  2016-0004 2016-01-10  2016   1  10  CONDUCTOR    MOTO  MASCULINO    18
# 4  2016-0005 2016-01-21  2016   1  21  CONDUCTOR    MOTO  MASCULINO    29
#
#   FECHA_FALLECIMIENTO
# 0          2016-01-01
# 1          2016-01-02
# 2          2016-01-03
# 3          2016-01-10
# 4          2016-02-01

# %% [markdown]
# Exportamos el dataset a un archivo CSV

# %%
victimas_df.to_csv('../Datasets/Homicidios_victimas.csv')

# %% [markdown]
# ## Merge entre el dataset hechos_df y victimas_df

# %%
hechos_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696 entries, 0 to 695
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     696 non-null    object
#  1   N_VICTIMAS             696 non-null    int64
#  2   FECHA                  696 non-null    datetime64[ns]
#  3   AAAA                   696 non-null    int64
#  4   MM                     696 non-null    int64
#  5   DD                     696 non-null    int64
#  6   HORA                   696 non-null    object
#  7   HH                     696 non-null    object
#  8   LUGAR_DEL_HECHO        696 non-null    object
#  9   TIPO_DE_CALLE          696 non-null    object
#  10  Calle                  696 non-null    object
#  11  Cruce                  696 non-null    bool
#  12  Dirección Normalizada  696 non-null    object
#  13  COMUNA                 696 non-null    int64
#  14  XY (CABA)              696 non-null    object
#  15  pos x                  693 non-null    object
#  16  pos y                  693 non-null    object
#  17  PARTICIPANTES          696 non-null    object
#  18  VICTIMA                696 non-null    object
#  19  ACUSADO                696 non-null    object
# dtypes: bool(1), datetime64[ns](1), int64(5), object(13)
# memory usage: 104.1+ KB

# %%
victimas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID_hecho             717 non-null    object
#  1   FECHA                717 non-null    datetime64[ns]
#  2   AAAA                 717 non-null    int64
#  3   MM                   717 non-null    int64
#  4   DD                   717 non-null    int64
#  5   ROL                  717 non-null    object
#  6   VICTIMA              717 non-null    object
#  7   SEXO                 717 non-null    object
#  8   EDAD                 717 non-null    int32
#  9   FECHA_FALLECIMIENTO  717 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), int32(1), int64(3), object(4)
# memory usage: 53.3+ KB

# %% [markdown]
# Dado que las columnas 'AAAA', 'MM', 'DD', 'FECHA' y 'V' se repiten entre los 2 datasets, se procede a eliminarlo las columnas duplicadas.

# %%
victimas_df = victimas_df.drop(columns=['FECHA', 'AAAA', 'MM', 'DD'])
hechos_df = hechos_df.drop(columns=['VICTIMA'])

# %%
victimas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID_hecho             717 non-null    object
#  1   ROL                  717 non-null    object
#  2   VICTIMA              717 non-null    object
#  3   SEXO                 717 non-null    object
#  4   EDAD                 717 non-null    int32
#  5   FECHA_FALLECIMIENTO  717 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int32(1), object(4)
# memory usage: 30.9+ KB

# %% [markdown]
# Realizamos el cambio de nombre de la columna 'ID_hecho' a 'ID'

# %%
victimas_df.rename(columns={'ID_hecho': 'ID'}, inplace=True)

# %%
victimas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   717 non-null    object
#  1   ROL                  717 non-null    object
#  2   VICTIMA              717 non-null    object
#  3   SEXO                 717 non-null    object
#  4   EDAD                 717 non-null    int32
#  5   FECHA_FALLECIMIENTO  717 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int32(1), object(4)
# memory usage: 30.9+ KB

# %%
hechos_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696 entries, 0 to 695
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     696 non-null    object
#  1   N_VICTIMAS             696 non-null    int64
#  2   FECHA                  696 non-null    datetime64[ns]
#  3   AAAA                   696 non-null    int64
#  4   MM                     696 non-null    int64
#  5   DD                     696 non-null    int64
#  6   HORA                   696 non-null    object
#  7   HH                     696 non-null    object
#  8   LUGAR_DEL_HECHO        696 non-null    object
#  9   TIPO_DE_CALLE          696 non-null    object
#  10  Calle                  696 non-null    object
#  11  Cruce                  696 non-null    bool
#  12  Dirección Normalizada  696 non-null    object
#  13  COMUNA                 696 non-null    int64
#  14  XY (CABA)              696 non-null    object
#  15  pos x                  693 non-null    object
#  16  pos y                  693 non-null    object
#  17  PARTICIPANTES          696 non-null    object
#  18  ACUSADO                696 non-null    object
# dtypes: bool(1), datetime64[ns](1), int64(5), object(12)
# memory usage: 98.7+ KB

# %% [markdown]
# Se realiza el merge entre el dataframe Hechos y Victimas, utilizando la columna ID para unión de los datos.

# %%
homicidios_df = pd.merge(hechos_df, victimas_df, on='ID', how='inner')
homicidios_df
# Out:
#             ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA  HH  \
# 0    2016-0001           1 2016-01-01  2016   1   1  04:00:00   4
# 1    2016-0002           1 2016-01-02  2016   1   2  01:15:00   1
# 2    2016-0003           1 2016-01-03  2016   1   3  07:00:00   7
# 3    2016-0004           1 2016-01-10  2016   1  10  00:00:00   0
# 4    2016-0005           1 2016-01-21  2016   1  21  05:20:00   5
# ..         ...         ...        ...   ...  ..  ..       ...  ..
# 712  2021-0093           1 2021-12-13  2021  12  13  17:10:00  17
# 713  2021-0094           1 2021-12-20  2021  12  20  01:10:00   1
# 714  2021-0095           1 2021-12-30  2021  12  30  00:43:00   0
# 715  2021-0096           1 2021-12-15  2021  12  15  10:30:00  10
# 716  2021-0097           1 2021-11-18  2021  11  18  06:10:00   6
#
#                                LUGAR_DEL_HECHO TIPO_DE_CALLE  ...  \
# 0    AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA  ...
# 1            AV GRAL PAZ  Y AV DE LOS CORRALES      GRAL PAZ  ...
# 2                           AV ENTRE RIOS 2034       AVENIDA  ...
# 3        AV LARRAZABAL Y GRAL VILLEGAS CONRADO       AVENIDA  ...
# 4    AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA        AVENIDA  ...
# ..                                         ...           ...  ...
# 712                          AV. RIESTRA Y MOM       AVENIDA  ...
# 713                    AU DELLEPIANE Y LACARRA     AUTOPISTA  ...
# 714                        AV. GAONA Y TERRADA       AVENIDA  ...
# 715                         AV. EVA PERON 4071       AVENIDA  ...
# 716                    PADRE CARLOS MUJICA 709         CALLE  ...
#
#                                    XY (CABA)         pos x         pos y  \
# 0      Point (98896.78238426 93532.43437792)  -58.47533969  -34.68757022
# 1      Point (95832.05571093 95505.41641999)  -58.50877521  -34.66977709
# 2     Point (106684.29090040 99706.57687843)  -58.39040293  -34.63189362
# 3      Point (99840.65224780 94269.16534422)  -58.46503904  -34.68092974
# 4    Point (106980.32827929 100752.16915795)  -58.38718297  -34.62246630
# ..                                       ...           ...           ...
# 712   Point (102728.60090138 98186.24929177)  -58.43353773  -34.64561636
# 713    Point (99624.29795829 97569.69801131)  -58.46739825  -34.65117757
# 714   Point (99116.45492358 101045.23284826)  -58.47293407  -34.61984745
# 715    Point (99324.54463985 97676.26932409)  -58.47066794  -34.65021673
# 716  Point (107664.16647795 104708.63962087)  -58.37976155  -34.58679619
#
#       PARTICIPANTES    ACUSADO                   ROL    VICTIMA       SEXO  \
# 0         MOTO-AUTO       AUTO             CONDUCTOR       MOTO  MASCULINO
# 1    AUTO-PASAJEROS  PASAJEROS             CONDUCTOR       AUTO  MASCULINO
# 2         MOTO-AUTO       AUTO             CONDUCTOR       MOTO  MASCULINO
# 3           MOTO-SD         SD             CONDUCTOR       MOTO  MASCULINO
# 4    MOTO-PASAJEROS  PASAJEROS             CONDUCTOR       MOTO  MASCULINO
# ..              ...        ...                   ...        ...        ...
# 712       MOTO-AUTO       AUTO  PASAJERO_ACOMPAÑANTE       MOTO   FEMENINO
# 713       MOTO-AUTO       AUTO  PASAJERO_ACOMPAÑANTE       MOTO   FEMENINO
# 714     MOTO-CARGAS     CARGAS             CONDUCTOR       MOTO  MASCULINO
# 715     AUTO-CARGAS     CARGAS             CONDUCTOR       AUTO  MASCULINO
# 716  BICICLETA-AUTO       AUTO              CICLISTA  BICICLETA  MASCULINO
#
#     EDAD FECHA_FALLECIMIENTO
# 0     19          2016-01-01
# 1     70          2016-01-02
# 2     30          2016-01-03
# 3     18          2016-01-10
# 4     29          2016-02-01
# ..   ...                 ...
# 712   18          2021-12-18
# 713   43          2021-12-20
# 714   27          2022-01-02
# 715   60          2021-12-20
# 716   53          2021-11-19
#
# [717 rows x 24 columns]

# %%
homicidios_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     717 non-null    object
#  1   N_VICTIMAS             717 non-null    int64
#  2   FECHA                  717 non-null    datetime64[ns]
#  3   AAAA                   717 non-null    int64
#  4   MM                     717 non-null    int64
#  5   DD                     717 non-null    int64
#  6   HORA                   717 non-null    object
#  7   HH                     717 non-null    object
#  8   LUGAR_DEL_HECHO        717 non-null    object
#  9   TIPO_DE_CALLE          717 non-null    object
#  10  Calle                  717 non-null    object
#  11  Cruce                  717 non-null    bool
#  12  Dirección Normalizada  717 non-null    object
#  13  COMUNA                 717 non-null    int64
#  14  XY (CABA)              717 non-null    object
#  15  pos x                  714 non-null    object
#  16  pos y                  714 non-null    object
#  17  PARTICIPANTES          717 non-null    object
#  18  ACUSADO                717 non-null    object
#  19  ROL                    717 non-null    object
#  20  VICTIMA                717 non-null    object
#  21  SEXO                   717 non-null    object
#  22  EDAD                   717 non-null    int32
#  23  FECHA_FALLECIMIENTO    717 non-null    datetime64[ns]
# dtypes: bool(1), datetime64[ns](2), int32(1), int64(5), object(15)
# memory usage: 126.9+ KB

# %%
homicidios_df[homicidios_df['N_VICTIMAS'] > 1].head(10)
# Out:
#             ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA  HH  \
# 29   2016-0041           2 2016-03-29  2016   3  29  11:00:00  11
# 30   2016-0041           2 2016-03-29  2016   3  29  11:00:00  11
# 98   2016-0126           2 2016-09-18  2016   9  18  22:45:00  22
# 99   2016-0126           2 2016-09-18  2016   9  18  22:45:00  22
# 163  2017-0026           2 2017-02-26  2017   2  26  05:15:00   5
# 164  2017-0026           2 2017-02-26  2017   2  26  05:15:00   5
# 173  2017-0035           3 2017-03-23  2017   3  23  05:00:00   5
# 174  2017-0035           3 2017-03-23  2017   3  23  05:00:00   5
# 175  2017-0035           3 2017-03-23  2017   3  23  05:00:00   5
# 176  2017-0036           2 2017-03-29  2017   3  29  18:00:00  18
#
#                                        LUGAR_DEL_HECHO TIPO_DE_CALLE  ...  \
# 29                      AV DIRECTORIO Y RIVERA INDARTE       AVENIDA  ...
# 30                      AV DIRECTORIO Y RIVERA INDARTE       AVENIDA  ...
# 98                                IRIGOYEN Y TINOGASTA         CALLE  ...
# 99                                IRIGOYEN Y TINOGASTA         CALLE  ...
# 163                       AV. PERITO MORENO Y FOURNIER       AVENIDA  ...
# 164                       AV. PERITO MORENO Y FOURNIER       AVENIDA  ...
# 173  AV. DR. TRISTAN ACHAVAL RODRIGUEZ Y BLVD. AZUC...       AVENIDA  ...
# 174  AV. DR. TRISTAN ACHAVAL RODRIGUEZ Y BLVD. AZUC...       AVENIDA  ...
# 175  AV. DR. TRISTAN ACHAVAL RODRIGUEZ Y BLVD. AZUC...       AVENIDA  ...
# 176                CURUPAYTI Y COLECTORA AV. GRAL. PAZ      GRAL PAZ  ...
#
#                                    XY (CABA)         pos x         pos y  \
# 29    Point (100232.38564985 99530.25843190)  -58.46076550  -34.63350444
# 30    Point (100232.38564985 99530.25843190)  -58.46076550  -34.63350444
# 98    Point (94275.54271123 100886.87954649)  -58.52572109  -34.62125906
# 99    Point (94275.54271123 100886.87954649)  -58.52572109  -34.62125906
# 163   Point (104113.67806500 97722.68219304)  -58.41842777  -34.64979057
# 164   Point (104113.67806500 97722.68219304)  -58.41842777  -34.64979057
# 173  Point (109583.11620052 102006.72069921)  -58.35881506  -34.61113641
# 174  Point (109583.11620052 102006.72069921)  -58.35881506  -34.61113641
# 175  Point (109583.11620052 102006.72069921)  -58.35881506  -34.61113641
# 176   Point (95300.18060161 105287.23850698)  -58.51452347  -34.58159762
#
#         PARTICIPANTES      ACUSADO                   ROL VICTIMA       SEXO  \
# 29        MOTO-CARGAS       CARGAS             CONDUCTOR    MOTO  MASCULINO
# 30        MOTO-CARGAS       CARGAS  PASAJERO_ACOMPAÑANTE    MOTO  MASCULINO
# 98        AUTO-CARGAS       CARGAS             CONDUCTOR    AUTO  MASCULINO
# 99        AUTO-CARGAS       CARGAS  PASAJERO_ACOMPAÑANTE    AUTO  MASCULINO
# 163  AUTO-OBJETO FIJO  OBJETO FIJO  PASAJERO_ACOMPAÑANTE    AUTO   FEMENINO
# 164  AUTO-OBJETO FIJO  OBJETO FIJO             CONDUCTOR    AUTO  MASCULINO
# 173  AUTO-OBJETO FIJO  OBJETO FIJO             CONDUCTOR    AUTO  MASCULINO
# 174  AUTO-OBJETO FIJO  OBJETO FIJO  PASAJERO_ACOMPAÑANTE    AUTO  MASCULINO
# 175  AUTO-OBJETO FIJO  OBJETO FIJO  PASAJERO_ACOMPAÑANTE    AUTO  MASCULINO
# 176    MOTO-PASAJEROS    PASAJEROS  PASAJERO_ACOMPAÑANTE    MOTO   FEMENINO
#
#     EDAD FECHA_FALLECIMIENTO
# 29    54          2016-03-29
# 30    39          2016-03-30
# 98    37          2016-09-18
# 99    60          2016-09-18
# 163   23          2017-02-26
# 164   19          2017-02-26
# 173   28          2017-03-23
# 174   32          2017-03-23
# 175   30          2017-03-23
# 176   50          2017-03-29
#
# [10 rows x 24 columns]

# %% [markdown]
# Exportamos el dataframe a CSV

# %%
homicidios_df.to_csv('../Datasets/homicidios_merge.csv')

# %% [markdown]
# ## Información poblacional del censo CABA 2022
# URL: https://censo.gob.ar/index.php/datos_definitivos_caba/

# %%
caba2022_df = pd.read_excel('../Datasets/c2022_caba_est_c1_1.xlsx', sheet_name='Editado')
caba2022_df
# Out:
#     Código     Comuna  Población 2010  Población 2022  Variación absoluta  \
# 0        2      Total         2890151         3121707              231556
# 1     2007   Comuna 1          205886          223554               17668
# 2     2014   Comuna 2          157932          161645                3713
# 3     2021   Comuna 3          187537          196240                8703
# 4     2028   Comuna 4          218245          229240               10995
# 5     2035   Comuna 5          179005          194271               15266
# 6     2042   Comuna 6          176076          203043               26967
# 7     2049   Comuna 7          220591          215896               -4695
# 8     2056   Comuna 8          187237          204367               17130
# 9     2063   Comuna 9          161797          169063                7266
# 10    2070  Comuna 10          166022          173004                6982
# 11    2077  Comuna 11          189832          204601               14769
# 12    2084  Comuna 12          200116          236887               36771
# 13    2091  Comuna 13          231331          264385               33054
# 14    2098  Comuna 14          225970          248635               22665
# 15    2105  Comuna 15          182574          196876               14302
#
#     Variación relativa (%)  Aumento poblacional (Anual)  Población 2016  \
# 0                      8.0                 19296.333333       3005929.0
# 1                      8.6                  1472.333333        214720.0
# 2                      2.4                   309.416667        159788.5
# 3                      4.6                   725.250000        191888.5
# 4                      5.0                   916.250000        223742.5
# 5                      8.5                  1272.166667        186638.0
# 6                     15.3                  2247.250000        189559.5
# 7                     -2.1                  -391.250000        218243.5
# 8                      9.1                  1427.500000        195802.0
# 9                      4.5                   605.500000        165430.0
# 10                     4.2                   581.833333        169513.0
# 11                     7.8                  1230.750000        197216.5
# 12                    18.4                  3064.250000        218501.5
# 13                    14.3                  2754.500000        247858.0
# 14                    10.0                  1888.750000        237302.5
# 15                     7.8                  1191.833333        189725.0
#
#     Población 2017  Población 2018  Población 2019  Población 2020  \
# 0     3.025225e+06    3.044522e+06      3063818.00    3.083114e+06
# 1     2.161923e+05    2.176647e+05       219137.00    2.206093e+05
# 2     1.600979e+05    1.604073e+05       160716.75    1.610262e+05
# 3     1.926138e+05    1.933390e+05       194064.25    1.947895e+05
# 4     2.246588e+05    2.255750e+05       226491.25    2.274075e+05
# 5     1.879102e+05    1.891823e+05       190454.50    1.917267e+05
# 6     1.918068e+05    1.940540e+05       196301.25    1.985485e+05
# 7     2.178522e+05    2.174610e+05       217069.75    2.166785e+05
# 8     1.972295e+05    1.986570e+05       200084.50    2.015120e+05
# 9     1.660355e+05    1.666410e+05       167246.50    1.678520e+05
# 10    1.700948e+05    1.706767e+05       171258.50    1.718403e+05
# 11    1.984472e+05    1.996780e+05       200908.75    2.021395e+05
# 12    2.215658e+05    2.246300e+05       227694.25    2.307585e+05
# 13    2.506125e+05    2.533670e+05       256121.50    2.588760e+05
# 14    2.391912e+05    2.410800e+05       242968.75    2.448575e+05
# 15    1.909168e+05    1.921087e+05       193300.50    1.944923e+05
#
#     Población 2021
# 0     3.102411e+06
# 1     2.220817e+05
# 2     1.613356e+05
# 3     1.955148e+05
# 4     2.283238e+05
# 5     1.929988e+05
# 6     2.007958e+05
# 7     2.162872e+05
# 8     2.029395e+05
# 9     1.684575e+05
# 10    1.724222e+05
# 11    2.033702e+05
# 12    2.338228e+05
# 13    2.616305e+05
# 14    2.467462e+05
# 15    1.956842e+05

# %%
caba2022_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Código                       16 non-null     int64
#  1   Comuna                       16 non-null     object
#  2   Población 2010               16 non-null     int64
#  3   Población 2022               16 non-null     int64
#  4   Variación absoluta           16 non-null     int64
#  5   Variación relativa (%)       16 non-null     float64
#  6   Aumento poblacional (Anual)  16 non-null     float64
#  7   Población 2016               16 non-null     float64
#  8   Población 2017               16 non-null     float64
#  9   Población 2018               16 non-null     float64
#  10  Población 2019               16 non-null     float64
#  11  Población 2020               16 non-null     float64
#  12  Población 2021               16 non-null     float64
# dtypes: float64(8), int64(4), object(1)
# memory usage: 1.8+ KB

# %% [markdown]
# ## KPIs

# %% [markdown]
# 1. Reducir en un 10% la tasa de homicidios en siniestros viales de los últimos seis meses, en CABA, en comparación con la tasa de homicidios en siniestros viales del semestre anterior.
#
# *Definimos a la tasa de homicidios en siniestros viales como el número de víctimas fatales en accidentes de tránsito por cada 100,000 habitantes en un área geográfica durante un período de tiempo específico. Su fórmula es: (Número de homicidios en siniestros viales / Población total) * 100,000*

# %%
homicidios_df
# Out:
#             ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA  HH  \
# 0    2016-0001           1 2016-01-01  2016   1   1  04:00:00   4
# 1    2016-0002           1 2016-01-02  2016   1   2  01:15:00   1
# 2    2016-0003           1 2016-01-03  2016   1   3  07:00:00   7
# 3    2016-0004           1 2016-01-10  2016   1  10  00:00:00   0
# 4    2016-0005           1 2016-01-21  2016   1  21  05:20:00   5
# ..         ...         ...        ...   ...  ..  ..       ...  ..
# 712  2021-0093           1 2021-12-13  2021  12  13  17:10:00  17
# 713  2021-0094           1 2021-12-20  2021  12  20  01:10:00   1
# 714  2021-0095           1 2021-12-30  2021  12  30  00:43:00   0
# 715  2021-0096           1 2021-12-15  2021  12  15  10:30:00  10
# 716  2021-0097           1 2021-11-18  2021  11  18  06:10:00   6
#
#                                LUGAR_DEL_HECHO TIPO_DE_CALLE  ...  \
# 0    AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA  ...
# 1            AV GRAL PAZ  Y AV DE LOS CORRALES      GRAL PAZ  ...
# 2                           AV ENTRE RIOS 2034       AVENIDA  ...
# 3        AV LARRAZABAL Y GRAL VILLEGAS CONRADO       AVENIDA  ...
# 4    AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA        AVENIDA  ...
# ..                                         ...           ...  ...
# 712                          AV. RIESTRA Y MOM       AVENIDA  ...
# 713                    AU DELLEPIANE Y LACARRA     AUTOPISTA  ...
# 714                        AV. GAONA Y TERRADA       AVENIDA  ...
# 715                         AV. EVA PERON 4071       AVENIDA  ...
# 716                    PADRE CARLOS MUJICA 709         CALLE  ...
#
#                                    XY (CABA)         pos x         pos y  \
# 0      Point (98896.78238426 93532.43437792)  -58.47533969  -34.68757022
# 1      Point (95832.05571093 95505.41641999)  -58.50877521  -34.66977709
# 2     Point (106684.29090040 99706.57687843)  -58.39040293  -34.63189362
# 3      Point (99840.65224780 94269.16534422)  -58.46503904  -34.68092974
# 4    Point (106980.32827929 100752.16915795)  -58.38718297  -34.62246630
# ..                                       ...           ...           ...
# 712   Point (102728.60090138 98186.24929177)  -58.43353773  -34.64561636
# 713    Point (99624.29795829 97569.69801131)  -58.46739825  -34.65117757
# 714   Point (99116.45492358 101045.23284826)  -58.47293407  -34.61984745
# 715    Point (99324.54463985 97676.26932409)  -58.47066794  -34.65021673
# 716  Point (107664.16647795 104708.63962087)  -58.37976155  -34.58679619
#
#       PARTICIPANTES    ACUSADO                   ROL    VICTIMA       SEXO  \
# 0         MOTO-AUTO       AUTO             CONDUCTOR       MOTO  MASCULINO
# 1    AUTO-PASAJEROS  PASAJEROS             CONDUCTOR       AUTO  MASCULINO
# 2         MOTO-AUTO       AUTO             CONDUCTOR       MOTO  MASCULINO
# 3           MOTO-SD         SD             CONDUCTOR       MOTO  MASCULINO
# 4    MOTO-PASAJEROS  PASAJEROS             CONDUCTOR       MOTO  MASCULINO
# ..              ...        ...                   ...        ...        ...
# 712       MOTO-AUTO       AUTO  PASAJERO_ACOMPAÑANTE       MOTO   FEMENINO
# 713       MOTO-AUTO       AUTO  PASAJERO_ACOMPAÑANTE       MOTO   FEMENINO
# 714     MOTO-CARGAS     CARGAS             CONDUCTOR       MOTO  MASCULINO
# 715     AUTO-CARGAS     CARGAS             CONDUCTOR       AUTO  MASCULINO
# 716  BICICLETA-AUTO       AUTO              CICLISTA  BICICLETA  MASCULINO
#
#     EDAD FECHA_FALLECIMIENTO
# 0     19          2016-01-01
# 1     70          2016-01-02
# 2     30          2016-01-03
# 3     18          2016-01-10
# 4     29          2016-02-01
# ..   ...                 ...
# 712   18          2021-12-18
# 713   43          2021-12-20
# 714   27          2022-01-02
# 715   60          2021-12-20
# 716   53          2021-11-19
#
# [717 rows x 24 columns]

# %% [markdown]
# Calcular la cantidad de muertes correspondientes a cada semestre de los años registrados en el dataframe `homicidios_df`

# %%
def determinar_semestre(mes):
    if 1 <= mes <= 6:
        return 1
    elif 7 <= mes <= 12:
        return 2
    else:
        return 'Mes incorrecto'

homicidios_df['Semestre'] = homicidios_df['MM'].apply(determinar_semestre)

# %%
homicidios_df.head()
# Out:
#           ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA HH  \
# 0  2016-0001           1 2016-01-01  2016   1   1  04:00:00  4
# 1  2016-0002           1 2016-01-02  2016   1   2  01:15:00  1
# 2  2016-0003           1 2016-01-03  2016   1   3  07:00:00  7
# 3  2016-0004           1 2016-01-10  2016   1  10  00:00:00  0
# 4  2016-0005           1 2016-01-21  2016   1  21  05:20:00  5
#
#                              LUGAR_DEL_HECHO TIPO_DE_CALLE  ...         pos x  \
# 0  AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA  ...  -58.47533969
# 1          AV GRAL PAZ  Y AV DE LOS CORRALES      GRAL PAZ  ...  -58.50877521
# 2                         AV ENTRE RIOS 2034       AVENIDA  ...  -58.39040293
# 3      AV LARRAZABAL Y GRAL VILLEGAS CONRADO       AVENIDA  ...  -58.46503904
# 4  AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA        AVENIDA  ...  -58.38718297
#
#           pos y   PARTICIPANTES    ACUSADO        ROL VICTIMA       SEXO EDAD  \
# 0  -34.68757022       MOTO-AUTO       AUTO  CONDUCTOR    MOTO  MASCULINO   19
# 1  -34.66977709  AUTO-PASAJEROS  PASAJEROS  CONDUCTOR    AUTO  MASCULINO   70
# 2  -34.63189362       MOTO-AUTO       AUTO  CONDUCTOR    MOTO  MASCULINO   30
# 3  -34.68092974         MOTO-SD         SD  CONDUCTOR    MOTO  MASCULINO   18
# 4  -34.62246630  MOTO-PASAJEROS  PASAJEROS  CONDUCTOR    MOTO  MASCULINO   29
#
#   FECHA_FALLECIMIENTO Semestre
# 0          2016-01-01        1
# 1          2016-01-02        1
# 2          2016-01-03        1
# 3          2016-01-10        1
# 4          2016-02-01        1
#
# [5 rows x 25 columns]

# %% [markdown]
# Agrupando los registros por año y semestre

# %%
victimas_semestre_df = homicidios_df.groupby(['AAAA', 'Semestre'])['N_VICTIMAS'].count().reset_index()
victimas_semestre_df
# Out:
#     AAAA  Semestre  N_VICTIMAS
# 0   2016         1          65
# 1   2016         2          81
# 2   2017         1          69
# 3   2017         2          71
# 4   2018         1          70
# 5   2018         2          79
# 6   2019         1          57
# 7   2019         2          47
# 8   2020         1          31
# 9   2020         2          50
# 10  2021         1          55
# 11  2021         2          42

# %%
victimas_semestre_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   AAAA        12 non-null     int64
#  1   Semestre    12 non-null     int64
#  2   N_VICTIMAS  12 non-null     int64
# dtypes: int64(3)
# memory usage: 420.0 bytes

# %% [markdown]
# Cambiamos de nombre la columna 'AAAA' a 'Año'

# %%
victimas_semestre_df.rename(columns={'AAAA': 'Año'}, inplace=True)

victimas_semestre_df
# Out:
#      Año  Semestre  N_VICTIMAS
# 0   2016         1          65
# 1   2016         2          81
# 2   2017         1          69
# 3   2017         2          71
# 4   2018         1          70
# 5   2018         2          79
# 6   2019         1          57
# 7   2019         2          47
# 8   2020         1          31
# 9   2020         2          50
# 10  2021         1          55
# 11  2021         2          42

# %% [markdown]
# Necesito obtener los datos correspondientes a la población total de la Ciudad Autónoma de Buenos Aires (CABA) para cada año a partir del DataFrame `caba2022_df`.

# %%
#Extraigo la información de población para cada año
poblacion_df= caba2022_df[['Población 2016','Población 2017', 'Población 2018','Población 2019', 
                                  'Población 2020', 'Población 2021']]

poblacion_df

#cambio nombres de las columnas
poblacion_df = poblacion_df.rename(columns={'Población 2016':'2016',
                                                        'Población 2017': '2017', 
                                                        'Población 2018': '2018',
                                                        'Población 2019': '2019', 
                                                        'Población 2020': '2020', 
                                                        'Población 2021': '2021'                  
                                                        })

# %%
poblacion_df
# Out:
#          2016          2017          2018        2019          2020  \
# 0   3005929.0  3.025225e+06  3.044522e+06  3063818.00  3.083114e+06
# 1    214720.0  2.161923e+05  2.176647e+05   219137.00  2.206093e+05
# 2    159788.5  1.600979e+05  1.604073e+05   160716.75  1.610262e+05
# 3    191888.5  1.926138e+05  1.933390e+05   194064.25  1.947895e+05
# 4    223742.5  2.246588e+05  2.255750e+05   226491.25  2.274075e+05
# 5    186638.0  1.879102e+05  1.891823e+05   190454.50  1.917267e+05
# 6    189559.5  1.918068e+05  1.940540e+05   196301.25  1.985485e+05
# 7    218243.5  2.178522e+05  2.174610e+05   217069.75  2.166785e+05
# 8    195802.0  1.972295e+05  1.986570e+05   200084.50  2.015120e+05
# 9    165430.0  1.660355e+05  1.666410e+05   167246.50  1.678520e+05
# 10   169513.0  1.700948e+05  1.706767e+05   171258.50  1.718403e+05
# 11   197216.5  1.984472e+05  1.996780e+05   200908.75  2.021395e+05
# 12   218501.5  2.215658e+05  2.246300e+05   227694.25  2.307585e+05
# 13   247858.0  2.506125e+05  2.533670e+05   256121.50  2.588760e+05
# 14   237302.5  2.391912e+05  2.410800e+05   242968.75  2.448575e+05
# 15   189725.0  1.909168e+05  1.921087e+05   193300.50  1.944923e+05
#
#             2021
# 0   3.102411e+06
# 1   2.220817e+05
# 2   1.613356e+05
# 3   1.955148e+05
# 4   2.283238e+05
# 5   1.929988e+05
# 6   2.007958e+05
# 7   2.162872e+05
# 8   2.029395e+05
# 9   1.684575e+05
# 10  1.724222e+05
# 11  2.033702e+05
# 12  2.338228e+05
# 13  2.616305e+05
# 14  2.467462e+05
# 15  1.956842e+05

# %% [markdown]
# Selecciono únicamente los datos de la primera fila, que corresponden a los valores totales.

# %%
poblacion_df = poblacion_df[:1]
poblacion_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2016    1 non-null      float64
#  1   2017    1 non-null      float64
#  2   2018    1 non-null      float64
#  3   2019    1 non-null      float64
#  4   2020    1 non-null      float64
#  5   2021    1 non-null      float64
# dtypes: float64(6)
# memory usage: 180.0 bytes

# %% [markdown]
# Reajusto la disposición del DataFrame para obtener el formato deseado de filas y columnas.

# %%
poblacion_año_df = pd.melt(poblacion_df, var_name='Año', value_name='Población Total').sort_values(by='Año')

# %%
poblacion_año_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Año              6 non-null      object
#  1   Población Total  6 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 228.0+ bytes

# %% [markdown]
# Modificando el tipo de dato de la columna 'Año' al tipo entero

# %%
poblacion_año_df['Año'] = poblacion_año_df['Año'].astype(int)

# %% [markdown]
# Unimos ambos dataframes para obtener el KPI 1

# %%
kpi1_df = pd.merge(victimas_semestre_df, poblacion_año_df, on='Año', how='left')
kpi1_df
# Out:
#      Año  Semestre  N_VICTIMAS  Población Total
# 0   2016         1          65     3.005929e+06
# 1   2016         2          81     3.005929e+06
# 2   2017         1          69     3.025225e+06
# 3   2017         2          71     3.025225e+06
# 4   2018         1          70     3.044522e+06
# 5   2018         2          79     3.044522e+06
# 6   2019         1          57     3.063818e+06
# 7   2019         2          47     3.063818e+06
# 8   2020         1          31     3.083114e+06
# 9   2020         2          50     3.083114e+06
# 10  2021         1          55     3.102411e+06
# 11  2021         2          42     3.102411e+06

# %% [markdown]
# Agregando la columna de tasa semestral por cada semestre

# %%
kpi1_df['Tasa semestral'] = kpi1_df['N_VICTIMAS']*100000/kpi1_df['Población Total']
kpi1_df
# Out:
#      Año  Semestre  N_VICTIMAS  Población Total  Tasa semestral
# 0   2016         1          65     3.005929e+06        2.162393
# 1   2016         2          81     3.005929e+06        2.694674
# 2   2017         1          69     3.025225e+06        2.280822
# 3   2017         2          71     3.025225e+06        2.346933
# 4   2018         1          70     3.044522e+06        2.299212
# 5   2018         2          79     3.044522e+06        2.594825
# 6   2019         1          57     3.063818e+06        1.860424
# 7   2019         2          47     3.063818e+06        1.534034
# 8   2020         1          31     3.083114e+06        1.005477
# 9   2020         2          50     3.083114e+06        1.621737
# 10  2021         1          55     3.102411e+06        1.772815
# 11  2021         2          42     3.102411e+06        1.353786

# %%
kpi1_df.to_csv('../Datasets/kpi1.csv')

# %% [markdown]
# 2. Reducir en un 7% la cantidad de accidentes mortales de motociclistas en el último año, en CABA, respecto al año anterior.
#
# *Definimos a la cantidad de accidentes mortales de motociclistas en siniestros viales como el número absoluto de accidentes fatales en los que estuvieron involucradas víctimas que viajaban en moto en un determinado periodo temporal. Su fórmula para medir la evolución de los accidentes mortales con víctimas en moto es: (Número de accidentes mortales con víctimas en moto en el año anterior - Número de accidentes mortales con víctimas en moto en el año actual) / (Número de accidentes mortales con víctimas en moto en el año anterior) * 100*

# %%
moticiclistas_df = homicidios_df[homicidios_df['VICTIMA']=='MOTO']
moticiclistas_df
# Out:
#             ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA  HH  \
# 0    2016-0001           1 2016-01-01  2016   1   1  04:00:00   4
# 2    2016-0003           1 2016-01-03  2016   1   3  07:00:00   7
# 3    2016-0004           1 2016-01-10  2016   1  10  00:00:00   0
# 4    2016-0005           1 2016-01-21  2016   1  21  05:20:00   5
# 5    2016-0008           1 2016-01-24  2016   1  24  18:30:00  18
# ..         ...         ...        ...   ...  ..  ..       ...  ..
# 708  2021-0089           1 2021-12-02  2021  12   2  01:10:00   1
# 710  2021-0091           1 2021-12-11  2021  12  11  23:00:00  23
# 712  2021-0093           1 2021-12-13  2021  12  13  17:10:00  17
# 713  2021-0094           1 2021-12-20  2021  12  20  01:10:00   1
# 714  2021-0095           1 2021-12-30  2021  12  30  00:43:00   0
#
#                                LUGAR_DEL_HECHO TIPO_DE_CALLE  ...  \
# 0    AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA  ...
# 2                           AV ENTRE RIOS 2034       AVENIDA  ...
# 3        AV LARRAZABAL Y GRAL VILLEGAS CONRADO       AVENIDA  ...
# 4    AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA        AVENIDA  ...
# 5               AV 27 DE FEBRERO Y AV ESCALADA       AVENIDA  ...
# ..                                         ...           ...  ...
# 708                             AV. GAONA 3655       AVENIDA  ...
# 710                    BAIGORRIA Y VICTOR HUGO         CALLE  ...
# 712                          AV. RIESTRA Y MOM       AVENIDA  ...
# 713                    AU DELLEPIANE Y LACARRA     AUTOPISTA  ...
# 714                        AV. GAONA Y TERRADA       AVENIDA  ...
#
#             pos x         pos y     PARTICIPANTES      ACUSADO  \
# 0    -58.47533969  -34.68757022         MOTO-AUTO         AUTO
# 2    -58.39040293  -34.63189362         MOTO-AUTO         AUTO
# 3    -58.46503904  -34.68092974           MOTO-SD           SD
# 4    -58.38718297  -34.62246630    MOTO-PASAJEROS    PASAJEROS
# 5    -58.44451316  -34.68475866  MOTO-OBJETO FIJO  OBJETO FIJO
# ..            ...           ...               ...          ...
# 708  -58.47633683  -34.62140594         MOTO-AUTO         AUTO
# 710  -58.51989389  -34.62284918         MOTO-AUTO         AUTO
# 712  -58.43353773  -34.64561636         MOTO-AUTO         AUTO
# 713  -58.46739825  -34.65117757         MOTO-AUTO         AUTO
# 714  -58.47293407  -34.61984745       MOTO-CARGAS       CARGAS
#
#                       ROL VICTIMA       SEXO EDAD FECHA_FALLECIMIENTO Semestre
# 0               CONDUCTOR    MOTO  MASCULINO   19          2016-01-01        1
# 2               CONDUCTOR    MOTO  MASCULINO   30          2016-01-03        1
# 3               CONDUCTOR    MOTO  MASCULINO   18          2016-01-10        1
# 4               CONDUCTOR    MOTO  MASCULINO   29          2016-02-01        1
# 5               CONDUCTOR    MOTO  MASCULINO   30          2016-01-24        1
# ..                    ...     ...        ...  ...                 ...      ...
# 708             CONDUCTOR    MOTO  MASCULINO   41          2021-12-11        2
# 710             CONDUCTOR    MOTO  MASCULINO   24          2021-12-11        2
# 712  PASAJERO_ACOMPAÑANTE    MOTO   FEMENINO   18          2021-12-18        2
# 713  PASAJERO_ACOMPAÑANTE    MOTO   FEMENINO   43          2021-12-20        2
# 714             CONDUCTOR    MOTO  MASCULINO   27          2022-01-02        2
#
# [303 rows x 25 columns]

# %%
motos_accidentes_df = moticiclistas_df.groupby('AAAA')['VICTIMA'].count().reset_index()
motos_accidentes_df
# Out:
#    AAAA  VICTIMA
# 0  2016       65
# 1  2017       56
# 2  2018       57
# 3  2019       50
# 4  2020       29
# 5  2021       46

# %%
motos_accidentes_df.rename(columns={'AAAA': 'Año'}, inplace=True)
motos_accidentes_df
# Out:
#     Año  VICTIMA
# 0  2016       65
# 1  2017       56
# 2  2018       57
# 3  2019       50
# 4  2020       29
# 5  2021       46

# %%
motos_accidentes_df['Año'] = motos_accidentes_df['Año'].astype(int)

# %%
kpi2_df = pd.merge(motos_accidentes_df, poblacion_año_df, on='Año', how='left')
kpi2_df
# Out:
#     Año  VICTIMA  Población Total
# 0  2016       65     3.005929e+06
# 1  2017       56     3.025225e+06
# 2  2018       57     3.044522e+06
# 3  2019       50     3.063818e+06
# 4  2020       29     3.083114e+06
# 5  2021       46     3.102411e+06

# %%
kpi2_df["Víctimas año anterior"] = kpi2_df["VICTIMA"].shift(periods=1, fill_value=0)
kpi2_df
# Out:
#     Año  VICTIMA  Población Total  Víctimas año anterior
# 0  2016       65     3.005929e+06                      0
# 1  2017       56     3.025225e+06                     65
# 2  2018       57     3.044522e+06                     56
# 3  2019       50     3.063818e+06                     57
# 4  2020       29     3.083114e+06                     50
# 5  2021       46     3.102411e+06                     29

# %%
kpi2_df['Evolución']= (kpi2_df['Víctimas año anterior']-kpi2_df['VICTIMA'])*100/kpi2_df['Víctimas año anterior']
kpi2_df
# Out:
#     Año  VICTIMA  Población Total  Víctimas año anterior  Evolución
# 0  2016       65     3.005929e+06                      0       -inf
# 1  2017       56     3.025225e+06                     65  13.846154
# 2  2018       57     3.044522e+06                     56  -1.785714
# 3  2019       50     3.063818e+06                     57  12.280702
# 4  2020       29     3.083114e+06                     50  42.000000
# 5  2021       46     3.102411e+06                     29 -58.620690

# %%
kpi2_df = kpi2_df.rename(columns={'VICTIMA':'Cantidad de víctimas' })

# %%
kpi2_df.to_csv('../Datasets/kpi2.csv')
